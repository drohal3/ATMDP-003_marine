# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

path = "../local/Tvarminne/vocus_data/Full_VOC_cleaned_RB.csv"

df = pd.read_csv(path, engine="pyarrow")
df["Time"] = pd.to_datetime(df["Time"], format="%d-%b-%Y %H:%M:%S", errors='coerce')
df.set_index("Time", inplace=True)

for col in df.columns:
    df[col] = df[col].mask(df[col] < 0, np.nan) 

df = df.resample("h").median()

print(df.dtypes)
print(df.index.dtype)
print(df.head())
print(df.shape)

df.to_csv("../local/Tvarminne/preprocessed_all/vocs_many.csv", index=True, date_format="%Y-%m-%d %H:%M:%S")
# Out:
# DMS_ppt         float64
# IP_ppt          float64
# MTS_ppt         float64
# C3H5_ppt        float64
# C3H7_ppt        float64
# C4H9_ppt        float64
# C5H11_ppt       float64
# C6H13_ppt       float64
# C8H13_ppt       float64
# C11H17_ppt      float64
# C10H17O_ppt     float64
# C10H21O_ppt     float64
# C10H23O2_ppt    float64
# C12H23O3_ppt    float64
# C12H25O3_ppt    float64
# C13H21O_ppt     float64
# C13H23O_ppt     float64
# C15H27O_ppt     float64
# dtype: object
# datetime64[s]
#                       DMS_ppt      IP_ppt    MTS_ppt  C3H5_ppt  C3H7_ppt  \
# Time
# 2023-12-21 07:00:00  0.196554  132.149160  53.941985  0.766738  0.381537
# 2023-12-21 08:00:00  2.123797  241.546178  23.344082  1.451091  0.425196
# 2023-12-21 09:00:00  2.297495  188.234121  19.511382  0.964577  0.415496
# 2023-12-21 10:00:00  1.872613  129.172730  16.063190  0.763691  0.359265
# 2023-12-21 11:00:00  2.627639  104.275456  17.090603  0.669234  0.337543
#
#                        C4H9_ppt  C5H11_ppt  C6H13_ppt  C8H13_ppt  C11H17_ppt  \
# Time
# 2023-12-21 07:00:00  113.424072  39.812943  19.567889  16.347927    2.041692
# 2023-12-21 08:00:00  283.813660  45.006511  23.356191  30.902023    2.296921
# 2023-12-21 09:00:00  149.096484  45.705186  23.982955  25.367772    2.474289
# 2023-12-21 10:00:00  106.622909  37.456462  20.388465  20.089627    2.025857
# 2023-12-21 11:00:00   86.828127  32.395862  17.723029  17.214313    1.861241
#
#                      C10H17O_ppt  C10H21O_ppt  C10H23O2_ppt  C12H23O3_ppt  \
# Time
# 2023-12-21 07:00:00     5.547907     8.904901      6.494559      0.444488
# 2023-12-21 08:00:00     3.794210    13.439448     10.393307      0.486577
# 2023-12-21 09:00:00     3.688939    13.737230     10.450348      0.484946
# 2023-12-21 10:00:00     3.842817    13.786052     10.492557      0.452102
# 2023-12-21 11:00:00     4.223170    11.760505      9.213016      0.427349
#
#                      C12H25O3_ppt  C13H21O_ppt  C13H23O_ppt  C15H27O_ppt
# Time
# 2023-12-21 07:00:00      0.580938     0.305140     0.687987     0.307215
# 2023-12-21 08:00:00      0.642242     0.485201     1.531675     0.321240
# 2023-12-21 09:00:00      0.660638     0.432572     1.040323     0.322111
# 2023-12-21 10:00:00      0.602001     0.362546     0.888646     0.297157
# 2023-12-21 11:00:00      0.558638     0.333354     0.791275     0.275841
# (15592, 18)
